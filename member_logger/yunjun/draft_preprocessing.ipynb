# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
src = cv2.imread('/Users/xiayunj/Desktop/Capstone/test.jpg')
image = cv2.flip(src, 1)
plt.imshow(image)

# %%
cv2.imwrite('/Users/xiayunj/Desktop/Capstone/test_flip.jpg', image)
# Out:
# True

# %%
import glob
filenames = glob.glob("/Users/xiayunj/Desktop/Capstone/test/*.jpg")

# %%
for i in range(30):
    path = filenames[i]
    pic = cv2.imread(path)
    if(path[48] == 'R'):
        image = cv2.flip(pic, 1)
        cv2.imwrite('/Users/xiayunj/Desktop/Capstone/res/' + path[37:], image)
    else:
        cv2.imwrite('/Users/xiayunj/Desktop/Capstone/res/' + path[37:], pic)
